# %% [markdown]
# #Python Assignment 1

# %% [markdown]
# 1> Explain the key features of python that make it a popular choice of programming.
#
# --> a) Syntax is quite easy to learn and write & for the same reason it is
#        beginner friendly. Readability is good.
#     b) Provide extensive library support & frameworks for web development and
#        data analysis , AI/ML like Django,Pandas, sci-kit learn. etc.
#     c) Python is a cross-platform and works on Windows, Mac, and Linux.
#
# 2> Describe the role of predefined keywords in python and provide examples      of how they are used in a program ?
#
# --> Predefined keywords are reserved words that have special meaning and serve specific purposes in the language syntax. It can not be used as names of function, classes and variables. Keywords are case sensitive and can not be redefined or overridden within a python program. Some examples of keywords are True, False, if, else, while, for, try, import etc.
# Few examples of their uses in program:
#    a) True -> if True:
#                 print("This will always execute")
#    b) False -> if False:
#                   print("This will never execute")
#    c) if -> if a > b:
#                print("a is greater than b")
#    d) while -> count = 0
#                while (count < 3):
#                  count = count + 1
#                  print("Hello PW")
#
# 3> Compare and contrast mutable and immutable objects in python with examples.
#
# --> a) In Python, objects can be either changeable  or unchangeable .
#     b) Mutable objects, such as lists and dictionaries, can be modified after creation, while immutable objects, such as tuples and strings, cannot.
#     examples : list --> removing elements from list:
#                           a = [10, 20, 30, 40, 50]
#                           # Removes the first occurrence of 30
#                            a.remove(30)
#                            print("After remove(30):", a)
#                    output: After remove(30):  a = [10, 20, 40, 50]
#                dictionary --> Modifying a dictionary
#                           student_info = {"name": "Alice", "age": 25, "course": "Python"}
#                            # Modifying an existing value
#                              student_info["age"] = 26
#
#                            output :  student_info = {"name": "Alice", "age": 26, "course": "Python"}
#      c) Mutability affects how objects are stored and manipulated in memory, impacting performance, memory usage, and concurrency in Python programs.
#
#
#  4> Discuss the different types of operators in python and provide examples of how they are used .
#
#  --> a) Addition operator (+): We can use the plus sign (+) to add two
#         numbers.
#         example : a = 6
#                   b = 3
#                   print(a + b)  # prints 9
#
#      b) Subtraction operator (-): We can use the minus sign (-) to subtract
#         one number from another.
#         example : a = 6
#                   b = 3
#                   print(a - b)  # prints 3
#
#      c) Multiplication Operator (*): We can use asterisk (*) to multiply
#         two numbers.
#         example : a = 6
#                   b = 3
#                   print(a * b) #prints 18
#
#       d) Division operator (/) : We can use the forward slash (/) to divide one
#          number by another. This will give us a float (decimal number) as a result.
#          example : a = 6
#                    b = 3
#                    print(a / b)  # prints 2.0
#
#       e) Integer division (//): We can use the double forward slash (//) to
#          perform integer division. This will divide the numbers and return the whole number part of the result, discarding the remainder.
#          example :result = 10 // 3
#                   print(result)  # prints 3
#                   #In this example, 10 divided by 3 equals 3.333.... The integer division returns only the whole number part, which is 3.
#
#       f) Modulo (%): We can use the percent symbol (%), known as the modulo     operator, to get the remainder of a division.
#       example : a = 6
#                 b = 3
#                 print(a % b)  # prints 0
#
#       g) Exponentiation (**): We can use the double asterisk (**) to raise a
#          number to the power of another number.
#          example : a = 6
#                    b = 3
#                    print(a ** b)  # prints 216
#
#       h) Relational operator :  - a > b   (Checks if `a` is greater than `b`)
#                                 - a == b  (Checks if `a` is equal to `b`)
#                                 - a != b  (Checks if `a` is not equal to `b`)
#                                 - a >= b  (Checks if `a` is greater than or equal to `b`)
#                                 - a <= b  (Checks if `a` is less than or equal to `b`)
#
#       i) Logical operators : Logical operators help us combine multiple         conditions to check if they are True or False. They are often used to make decisions based on multiple criteria.
#
#           1) Logical AND : # The AND operator returns True only if both conditions are True.
#
#               a = 7
#               condition = a > 5 and a < 10  # Only True if a is greater than 5 AND less than 10
#               print(condition)  # Output: True
#
#           2) Logical OR : # The OR operator returns True if at least one of the
#              conditions is True.
#
#             a = 7
#             condition = a > 10 or a < 5  # True if a is greater than 10 OR less than 5
#             print(condition)  # Output: False
#
#           3) Logical NOT : # The NOT operator reverses the result of the condition. If the condition is True, `not` makes it False. If the condition is False, `not` makes it True.
#
#               a = 7
#               condition = not(a > 5)  # Reverses the result of a > 5
#               print(condition)  # Output: False
#
#
#  5> Explain the concept of type casting in python with  examples.
#
#  -->  There can be two type of type casting in python : a) Implicit type  casting  and b) Explicit type casting.
#    a) Implicit type casting : In this method , python converts the datatype into another datatype automatically.
#       example: a = 7
#               print(type(a))
#               output: < class 'int'>
#
#                b = 3.0
#                print(type(b))
#                output: < class 'float'>
#
#     b) Explicit type casting : In this method, python needs user involvement to convert the data type into required data type. Functions used to do explicit type casting:
#      1) int(): function take float or string as an argument and returns int type object.
#      example:  # Python program to demonstrate
#                # type Casting
#
#                # float variable
#                a = 5.0
#
#                # typecast to int
#                n = int(a)
#
#                print(n)
#                print(type(n))
#
#                output: 5
#                        <class 'int'>
#
#         2)  float():  converts int to   float.
#             example:  a = 5
#                       n = float(a)
#                       print(n)
#                       output: 5.0
#
#         3) str(): convert int to string.
#           example: a = 5
#                    n = str(a)
#                    print(n)
#                    output: '5'
#
#
#  6> How do conditional statements work in python ? Illustrate with examples.
#
#  --> Conditional statements in python are used to execute certain blocks of code based on specific conditions. These statements help in controlling the flow of programe.
#
#  examples: a) if conditional statment: if statement is the simplest form of conditional statment. It executes a block of code if the given condition is true.
#          a = 20
#          if age >= 18:
#              print("Eligible to vaote.")
#
#          output: Eligible to vote.
#
#          b) if else conditional statement in python: Else allows us to specify a block of code that will execute if the condition associated with an if or elif statement evaluates to False.
#
#                 age = 10
#                 if age <= 12:
#                     print("Travel for free.")
#                else:
#                     print("Pay for ticket.")
#
#              output: Travel for free.
#
#           c) elif statment : elif statement stands for "else if".  It allows us to check multiple conditions , providing a way to execute different blocks of code based on which condition is true.
#
#                age = 25
#                if age <= 12:
#                    print("Child.")
#                elif age <= 19:
#                    print("Teenager.")
#                elif age <= 35:
#                    print("Young adult.")
#                else:
#                   print("Adult.")
#
#                output: Young adult.
#
#           d) Neted if else statment: It means an if-else statement inside another if statement. We can use nested if statements to check conditions within conditions.
#
#                 age = 70
#                 is_member = True
#                 if age >= 60:
#                    if is_member:
#                       print("30% senior discount!")
#                    else:
#                       print("20% senior discount.")
#                else:
#                    print("Not eligible for a senior discount.")
#
#                   output: 30% senior discount!
#
#
# 7> Describe the different types of loops in python and their use cases in python.
#
# -->  Loops in python are used to perform specific action repeatedly. There are basically two types of loops in python: While loop and for loop.
#
#        a) while loop: while loop is used to execute a block of statements repeatedly until a given condition is satisfied. When the condition becomes false, the line immediately after the loop in the program is executed.
#
#        syntax: while condition:
#                     statments
#
#        example of while loop:
#
#                          cnt = 0
#                          while (cnt < 3):
#                             cnt = cnt + 1
#                             print("Hello pwskills")
#
#                             output:  Hello pwskills
#                                      Hello pwskills
#                                      Hello pwskills
#
#       Use of else statment with while loop in python: Else clause is only executed when our while condition becomes false. If we break out of the loop or if an exception is raised then it won’t be executed.
#
#       Syntax:       while condition:
#                         # execute these statements
#                     else:
#                         # execute these statements
#
#
#       example:  cnt = 0
#                 while (cnt < 3):
#                     cnt = cnt + 1
#                     print("Hello pwskills")
#                 else:
#                     print("In Else Block")
#
#                     outpit:  Hello pwskills
#                              Hello pwskills
#                              Hello pwskills
#                              In Else Block
#
#
#
#            b) for loop : for loops are used for sequential traversal. like for traversing a list or string.
#
#            example:   n = 4
#                       for i in range(0, n):
#                            print(i)
#
#                            output:  0
#                                     1
#                                     2
#                                     3
#
#
#           Explanation: This code prints the numbers from 0 to 3 (inclusive) using a for loop that iterates over a range from 0 to n-1 (where n = 4).
#
#
#           continue statements :   The continue statements in Python returns the control to the beginning of the loop.
#
#           example:    for letter in 'pwskills':
#                           if letter == 'w' or letter == 'i':
#                               continue
#                           print('Current Letter :', letter)
#
#                           output:   Current Letter : p
#                                     Current Letter : s
#                                     Current Letter : k
#                                     Current Letter : l
#                                     Current Letter : l
#                                     Current Letter : s
#
#
#            Explanation: The continue statement is used to skip the current iteration of a loop and move to the next iteration. It is useful when we want to bypass certain conditions without terminating the loop.
#
#
#            break statement: The break statements brings control out of the loop.
#
#            example: for letter in 'pwskills':
#                         if letter == 'k' or letter == 's':
#                           break
#                     print('Current Letter :', letter)
#
#                     output: current letter : k
#
#             Explanation: break statement is used to exit the loop prematurely when a specified condition is met. In this example, the loop breaks when the letter is either "k" or "s", stopping further iteration.
